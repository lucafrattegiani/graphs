# %% [markdown]
# # **Libraries**

# %%
#Mathematics and ML
import torch

#Project package
from graphtools import graphon

#Autoreload module
"""
These magic lines allow to automatically reload any module.py file when there are some changes on it, without the needing of restart the kernel anytime a new change is applied to the module script
"""
# %load_ext autoreload
# %autoreload 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Sample W-random graph
K = 5 #Number of states
n = 100 #Number of nodes

#Edges structure
structure = "ring" #Graphon function

#Position structure
positions = "ring" #Position generator

#Node states
state = "hard" #State generator
state_kwargs = {"K": K} #State generator parameters

graph = graphon.sample_graph(n, device = device, structure = structure, positions = positions, state = state, state_kwargs = state_kwargs)
graph
# Out:
# Data(edge_index=[2, 1964], num_nodes=100, x=[100, 5], pos=[100, 2])

# %%
#Plot adjacency matrix and node positions
graphon.plot_graph(graph)
